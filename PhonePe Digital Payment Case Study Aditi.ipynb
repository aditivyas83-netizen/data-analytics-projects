# %% [markdown]
# ### PhonePe Case Study

# %% [markdown]
# ### Task1: Data loading and understanding

# %% [markdown]
# ### 1.1 Load each dataset and display it's structure

# %%
import pandas as pd

# %% [markdown]
# ### Load the State_Txn dataset and Users and display the first 5 rows

# %%
State_txn =pd.read_excel("C:\\Users\\Administrator\\Downloads\\Phonepe case study dataset.xlsx",sheet_name='State_Txn and Users')

# %%
State_txn.head()
# Out:
#                        State  Year  Quarter  Transactions  Amount (INR)  \
# 0  Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1  Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2  Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3  Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4  Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
#
#      ATV (INR)  Registered Users  App Opens
# 0  2197.621091              6740          0
# 1  2498.989022              9405          0
# 2  3415.768284             12149          0
# 3  3811.277720             15222          0
# 4  3355.630147             18596          0

# %% [markdown]
# ### Load the State_TxnSplit dataset and display its bottom 10 rows

# %%
State_TxnSplit =pd.read_excel("C:\\Users\\Administrator\\Downloads\\Phonepe case study dataset.xlsx",sheet_name='State_TxnSplit')

# %%
State_TxnSplit.tail(10)
# Out:
#             State  Year  Quarter          Transaction Type  Transactions  \
# 2504  West Bengal  2021        1     Peer-to-peer payments      53869075
# 2505  West Bengal  2021        1         Merchant payments      37143701
# 2506  West Bengal  2021        1  Recharge & bill payments      26673733
# 2507  West Bengal  2021        1        Financial Services        166727
# 2508  West Bengal  2021        1                    Others        400816
# 2509  West Bengal  2021        2     Peer-to-peer payments      64661051
# 2510  West Bengal  2021        2         Merchant payments      41696787
# 2511  West Bengal  2021        2  Recharge & bill payments      34799709
# 2512  West Bengal  2021        2        Financial Services        190537
# 2513  West Bengal  2021        2                    Others        549353
#
#       Amount (INR)    ATV (INR)
# 2504  2.022402e+11  3754.292226
# 2505  2.891834e+10   778.553104
# 2506  1.133967e+10   425.124820
# 2507  1.754458e+08  1052.293941
# ...

# %% [markdown]
# ### Load the State_DeviceData dataset and display 10 rows from the middle of the dataset

# %%
State_DeviceData =pd.read_excel("C:\\Users\\Administrator\\Downloads\\Phonepe case study dataset.xlsx",sheet_name='State_DeviceData')

# %%
State_DeviceData.shape[0]
# Out:
# 5544

# %%
middle_row = State_DeviceData.shape[0]//2
middle_row
# Out:
# 2772

# %%
State_DeviceData.loc[middle_row:middle_row +9]
# Out:
#             State  Year  Quarter    Brand  Registered Users  Percentage
# 2772  Lakshadweep  2018        1  Samsung               102    0.203593
# 2773  Lakshadweep  2018        1   Xiaomi               100    0.199601
# 2774  Lakshadweep  2018        1     Vivo                67    0.133733
# 2775  Lakshadweep  2018        1     Oppo                56    0.111776
# 2776  Lakshadweep  2018        1   Huawei                25    0.049900
# 2777  Lakshadweep  2018        1  OnePlus                22    0.043912
# 2778  Lakshadweep  2018        1    Apple                20    0.039920
# 2779  Lakshadweep  2018        1   Realme                20    0.039920
# 2780  Lakshadweep  2018        1   Gionee                12    0.023952
# 2781  Lakshadweep  2018        1  COOLPAD                10    0.019960

# %% [markdown]
# ### Load District_txn_and_Users dataset and display its first 10 rows and last 10 rows

# %%
District_Txn_and_Users =pd.read_excel("C:\\Users\\Administrator\\Downloads\\Phonepe case study dataset.xlsx",sheet_name='District_Txn and Users')

# %%
District_Txn_and_Users.head(10) # First 10 raws
# Out:
#                        State  Year  Quarter                  District  Code  \
# 0  Andaman & Nicobar Islands  2018        1                  Nicobars  AN01
# 1  Andaman & Nicobar Islands  2018        1  North And Middle Andaman  AN02
# 2  Andaman & Nicobar Islands  2018        1             South Andaman  AN03
# 3  Andaman & Nicobar Islands  2018        2                  Nicobars  AN01
# 4  Andaman & Nicobar Islands  2018        2  North And Middle Andaman  AN02
# 5  Andaman & Nicobar Islands  2018        2             South Andaman  AN03
# 6  Andaman & Nicobar Islands  2018        3                  Nicobars  AN01
# 7  Andaman & Nicobar Islands  2018        3  North And Middle Andaman  AN02
# 8  Andaman & Nicobar Islands  2018        3             South Andaman  AN03
# 9  Andaman & Nicobar Islands  2018        4                  Nicobars  AN01
#
#    Transactions  Amount (INR)    ATV (INR)  Registered Users  App Opens
# ...

# %%
District_Txn_and_Users.tail(10) # last 10 raws
# Out:
#              State  Year  Quarter                    District  Code  \
# 10238  West Bengal  2021        2                 Murshidabad  WB14
# 10239  West Bengal  2021        2                       Nadia  WB15
# 10240  West Bengal  2021        2  North Twenty Four Parganas  WB16
# 10241  West Bengal  2021        2           Paschim Bardhaman  WB17
# 10242  West Bengal  2021        2           Paschim Medinipur  WB18
# 10243  West Bengal  2021        2             Purba Bardhaman  WB19
# 10244  West Bengal  2021        2             Purba Medinipur  WB20
# 10245  West Bengal  2021        2                     Purulia  WB21
# 10246  West Bengal  2021        2  South Twenty Four Parganas  WB22
# 10247  West Bengal  2021        2              Uttar Dinajpur  WB23
#
#        Transactions  Amount (INR)    ATV (INR)  Registered Users  App Opens
# 10238       8602251  1.999694e+10  2324.616616           1248602   16530655
# ...

# %% [markdown]
# ###Load District_Demographics dataset and display every 10th row

# %%
District_Demographics =pd.read_excel("C:\\Users\\Administrator\\Downloads\\Phonepe case study dataset.xlsx",sheet_name='District Demographics')

# %% [markdown]
# displaying every 10th row in District Demographics

# %%
District_Demographics.loc[0::10]
# Out:
#                  State       District   Headquarters  Population  \
# 0       Andhra Pradesh      Anantapur      Anantapur     4083315
# 10      Andhra Pradesh  Visakhapatnam  Visakhapatnam     4288113
# 20   Arunachal Pradesh      Lepa Rada          Basar           0
# 30   Arunachal Pradesh          Siang         Pangin       31920
# 40               Assam        Barpeta        Barpeta     1693622
# ..                 ...            ...            ...         ...
# 700         Chandigarh     Chandigarh     Chandigarh     1055450
# 710    Jammu & Kashmir          Jammu          Jammu     1526406
# 720    Jammu & Kashmir          Samba          Samba      318611
# 730              Delhi    North Delhi   Sadar Bazaar      887978
# 740         Puducherry     Puducherry    Pondicherry      950289
#
#      Area (sq km)  Density  Code Alternate Name
# 0         19130.0      213  AP01      Anantapur
# 10        11161.0      384  AP10  Visakhapatnam
# ...

# %% [markdown]
# ### 1.2: Display basic Statistics and Datatype for each Dataset

# %% [markdown]
# ### 1 Statical Information

# %%
State_txn.describe()
# Out:
#               Year     Quarter  Transactions  Amount (INR)    ATV (INR)  \
# count   504.000000  504.000000  5.040000e+02  5.030000e+02   504.000000
# mean   2019.285714    2.357143  4.074000e+07  7.083332e+10  1993.471543
# std       1.031181    1.109971  8.228714e+07  1.440902e+11   607.464894
# min    2018.000000    1.000000  7.780000e+02  1.928611e+06     0.000000
# 25%    2018.000000    1.000000  5.925578e+05  1.167157e+09  1598.910667
# 50%    2019.000000    2.000000  6.217487e+06  1.051605e+10  1861.380589
# 75%    2020.000000    3.000000  4.363675e+07  6.947045e+10  2259.087924
# max    2021.000000    4.000000  5.736165e+08  1.027958e+12  3938.733850
#
#        Registered Users     App Opens
# count      5.040000e+02  5.040000e+02
# mean       4.777501e+06  9.774471e+07
# std        6.644496e+06  2.042376e+08
# min        5.010000e+02  0.000000e+00
# 25%        1.574202e+05  0.000000e+00
# 50%        1.747914e+06  2.930574e+06
# 75%        7.320945e+06  8.615022e+07
# ...

# %%
State_TxnSplit.describe()
# Out:
#               Year      Quarter  Transactions  Amount (INR)    ATV (INR)
# count  2514.000000  2514.000000  2.514000e+03  2.514000e+03  2514.000000
# mean   2019.286794     2.358393  8.167446e+06  1.443978e+10  1349.927929
# std       1.030807     1.109251  2.423645e+07  5.995054e+10  1534.866221
# min    2018.000000     1.000000  2.000000e+00  3.439721e+01    17.198606
# 25%    2018.000000     1.000000  2.788075e+04  1.762412e+07   385.735827
# 50%    2019.000000     2.000000  2.687980e+05  1.901189e+08   720.940406
# 75%    2020.000000     3.000000  3.683230e+06  2.661248e+09  1352.790116
# max    2021.000000     4.000000  2.795990e+08  8.721520e+11  7767.539936

# %%
State_DeviceData.describe()
# Out:
#               Year      Quarter  Registered Users   Percentage
# count  5544.000000  5544.000000      5.544000e+03  5544.000000
# mean   2019.285714     2.357143      4.343183e+05     0.090909
# std       1.030250     1.108970      9.056069e+05     0.083095
# min    2018.000000     1.000000      1.000000e+01     0.006373
# 25%    2018.000000     1.000000      8.055750e+03     0.021588
# 50%    2019.000000     2.000000      7.442250e+04     0.056914
# 75%    2020.000000     3.000000      3.978875e+05     0.143626
# max    2021.000000     4.000000      9.764252e+06     0.478367

# %%
District_Txn_and_Users.describe()
# Out:
#                Year       Quarter  Transactions  Amount (INR)     ATV (INR)  \
# count  10248.000000  10248.000000  1.024800e+04  1.024800e+04  10244.000000
# mean    2019.285714      2.357143  2.003607e+06  3.542311e+09   1909.796545
# std        1.030208      1.108924  9.613466e+06  1.473154e+10    600.943349
# min     2018.000000      1.000000  0.000000e+00  0.000000e+00     84.944283
# 25%     2018.000000      1.000000  1.031418e+05  1.756668e+08   1554.589051
# 50%     2019.000000      2.000000  3.763065e+05  6.784562e+08   1863.135530
# 75%     2020.000000      3.000000  1.272815e+06  2.377256e+09   2203.083552
# max     2021.000000      4.000000  3.487128e+08  4.444224e+11  11209.980550
#
#        Registered Users     App Opens
# count      1.024800e+04  1.024800e+04
# mean       2.349591e+05  4.807117e+06
# std        4.605978e+05  1.562541e+07
# min        2.200000e+01  0.000000e+00
# 25%        3.619550e+04  0.000000e+00
# 50%        1.067640e+05  6.403025e+05
# ...

# %%
District_Demographics.describe()
# Out:
#          Population  Area (sq km)       Density
# count  7.420000e+02    742.000000    742.000000
# mean   1.668555e+06   4395.373120    838.512129
# std    1.458849e+06   4254.676124   2754.406896
# min    0.000000e+00      0.000000      0.000000
# 25%    6.530815e+05   2039.750000    198.000000
# 50%    1.322359e+06   3402.500000    353.000000
# 75%    2.297440e+06   5432.750000    686.250000
# max    1.008285e+07  45652.000000  36155.000000

# %% [markdown]
# ### 2. Datatype

# %%
State_txn.dtypes
# Out:
# State                object
# Year                  int64
# Quarter               int64
# Transactions          int64
# Amount (INR)        float64
# ATV (INR)           float64
# Registered Users      int64
# App Opens             int64
# dtype: object

# %%
State_TxnSplit.dtypes
# Out:
# State                object
# Year                  int64
# Quarter               int64
# Transaction Type     object
# Transactions          int64
# Amount (INR)        float64
# ATV (INR)           float64
# dtype: object

# %%
State_DeviceData.dtypes
# Out:
# State                object
# Year                  int64
# Quarter               int64
# Brand                object
# Registered Users      int64
# Percentage          float64
# dtype: object

# %%
District_Txn_and_Users.dtypes
# Out:
# State                object
# Year                  int64
# Quarter               int64
# District             object
# Code                 object
# Transactions          int64
# Amount (INR)        float64
# ATV (INR)           float64
# Registered Users      int64
# App Opens             int64
# dtype: object

# %%
District_Demographics.dtypes
# Out:
# State              object
# District           object
# Headquarters       object
# Population          int64
# Area (sq km)      float64
# Density             int64
# Code               object
# Alternate Name     object
# dtype: object

# %% [markdown]
# ### 1.3 Check for missing values

# %% [markdown]
# ### 1 Identify missing value in dataset

# %%
State_txn.isnull().sum()
# Out:
# State               0
# Year                0
# Quarter             0
# Transactions        0
# Amount (INR)        1
# ATV (INR)           0
# Registered Users    0
# App Opens           0
# dtype: int64

# %%
State_TxnSplit.isnull().sum()
# Out:
# State               0
# Year                0
# Quarter             0
# Transaction Type    0
# Transactions        0
# Amount (INR)        0
# ATV (INR)           0
# dtype: int64

# %%
State_DeviceData.isnull().sum()
# Out:
# State               0
# Year                0
# Quarter             0
# Brand               0
# Registered Users    0
# Percentage          0
# dtype: int64

# %%
District_Txn_and_Users.isnull().sum()
# Out:
# State                0
# Year                 0
# Quarter              0
# District             0
# Code                28
# Transactions         0
# Amount (INR)         0
# ATV (INR)            4
# Registered Users     0
# App Opens            0
# dtype: int64

# %%
District_Demographics.isnull().sum()
# Out:
# State             0
# District          0
# Headquarters      0
# Population        0
# Area (sq km)      0
# Density           0
# Code              0
# Alternate Name    0
# dtype: int64

# %% [markdown]
# #### observation
# 1.1 null in State_Txn in ATV column
#
# 2.28 null values in District_Txn_Users in code column

# %% [markdown]
# ### 2 Calculate the percentage of missing value

# %%
len(District_Txn_and_Users)
# Out:
# 10248

# %%
State_txn.isnull().sum()/len(State_txn)*100
# Out:
# State               0.000000
# Year                0.000000
# Quarter             0.000000
# Transactions        0.000000
# Amount (INR)        0.198413
# ATV (INR)           0.000000
# Registered Users    0.000000
# App Opens           0.000000
# dtype: float64

# %% [raw]
# District_Txn_and_Users.isnull().sum()/len(District_Txn_and_Users)*100

# %% [markdown]
# ### 3 Highlight which column has highest % of missing values in each dataset

# %%
(State_txn.isnull().sum()/len(State_txn)*100).sort_values(ascending = False)
# Out:
# Amount (INR)        0.198413
# State               0.000000
# Year                0.000000
# Quarter             0.000000
# Transactions        0.000000
# ATV (INR)           0.000000
# Registered Users    0.000000
# App Opens           0.000000
# dtype: float64

# %%
(District_Txn_and_Users.isnull().sum()/len(District_Txn_and_Users)*100).sort_values(ascending =False)
# Out:
# Code                0.273224
# ATV (INR)           0.039032
# State               0.000000
# Year                0.000000
# Quarter             0.000000
# District            0.000000
# Transactions        0.000000
# Amount (INR)        0.000000
# Registered Users    0.000000
# App Opens           0.000000
# dtype: float64

# %% [markdown]
# ### 1.4 Create a Summary

# %% [markdown]
# ### 1 Calculate the total number of States and the total number of Districts

# %%
District_Demographics.columns
# Out:
# Index(['State', 'District', 'Headquarters', 'Population', 'Area (sq km)',
#        'Density', 'Code', 'Alternate Name'],
#       dtype='object')

# %%
District_Demographics['District'].count()
# Out:
# 742

# %%
District_Demographics['District'].nunique()
# Out:
# 736

# %%
District_Demographics['State'].nunique()
# Out:
# 36

# %% [markdown]
# ### 2 Identify the state with the highest number of districts

# %%
districts_per_state = District_Demographics.groupby('State')['District'].count()

# %%
districts_per_state
# Out:
# State
# Andaman & Nicobar Islands                3
# Andhra Pradesh                          13
# Arunachal Pradesh                       25
# Assam                                   34
# Bihar                                   38
# Chandigarh                               1
# Chhattisgarh                            28
# Dadra & Nagar Haveli and Daman & Diu     3
# Delhi                                   11
# Goa                                      2
# Gujarat                                 33
# Haryana                                 22
# Himachal Pradesh                        12
# Jammu & Kashmir                         20
# Jharkhand                               24
# Karnataka                               31
# Kerala                                  14
# Ladakh                                   2
# Lakshadweep                              1
# Madhya Pradesh                          55
# Maharashtra                             36
# Manipur                                 16
# ...

# %%
districts_per_state.idxmax()
# Out:
# 'Uttar Pradesh'

# %% [markdown]
# ### observation
# 1.there are 736 DIstricts and 36 states
#
# 2.Uttar Pradesh is highest with 75 Districts

# %% [markdown]
# ### Task:2 Explotatory Data Analysis

# %% [markdown]
# ### 2.1 Analyse  transaction trend over the year for each state

# %% [markdown]
# ### 1 Calculate the total number of transaction and total transaction amount for each state over the years. display the result in tabular format

# %%
Total_transaction = State_txn.groupby(['State','Year'])['Transactions'].sum()

# %%
Total_transaction
# Out:
# State                      Year
# Andaman & Nicobar Islands  2018        58021
#                            2019       133104
#                            2020       446274
#                            2021       586166
# Andhra Pradesh             2018     77779112
#                                      ...
# Uttarakhand                2021     44608834
# West Bengal                2018    120011635
#                            2019    257900590
#                            2020    304222327
#                            2021    260151489
# Name: Transactions, Length: 144, dtype: int64

# %%
Total_transaction_amount = State_txn.groupby(['State','Year'])['Amount (INR)'].sum()

# %%
Total_transaction_amount
# Out:
# State                      Year
# Andaman & Nicobar Islands  2018    1.890761e+08
#                            2019    4.734648e+08
#                            2020    1.296423e+09
#                            2021    1.682854e+09
# Andhra Pradesh             2018    1.220720e+11
#                                        ...
# Uttarakhand                2021    7.727901e+10
# West Bengal                2018    1.115887e+11
#                            2019    2.660145e+11
#                            2020    5.527316e+11
#                            2021    5.223720e+11
# Name: Amount (INR), Length: 144, dtype: float64

# %%
State_txn.head(10)
# Out:
#                        State  Year  Quarter  Transactions  Amount (INR)  \
# 0  Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1  Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2  Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3  Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4  Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# 5  Andaman & Nicobar Islands  2019        2         33689  1.202547e+08
# 6  Andaman & Nicobar Islands  2019        3         33770  1.140718e+08
# 7  Andaman & Nicobar Islands  2019        4         35159  1.368385e+08
# 8  Andaman & Nicobar Islands  2020        1         41298  1.614763e+08
# 9  Andaman & Nicobar Islands  2020        2         62962  1.696450e+08
#
#      ATV (INR)  Registered Users  App Opens
# 0  2197.621091              6740          0
# 1  2498.989022              9405          0
# ...

# %%
Total_transaction=pd.crosstab(index=State_txn['State'],columns=State_txn['Year'],values=State_txn['Transactions'],aggfunc='sum')
Total_transaction
# Out:
# Year                                       2018       2019        2020  \
# State
# Andaman & Nicobar Islands                 58021     133104      446274
# Andhra Pradesh                         77779112  297180254   763616699
# Arunachal Pradesh                        435229    1314871     3547905
# Assam                                   8806777   22691015    47135224
# Bihar                                  44556885  131986927   266563978
# Chandigarh                              2383031    5884404     8861323
# Chhattisgarh                           13933118   45826483    98023091
# Dadra & Nagar Haveli and Daman & Diu    1044832    2559192     4807834
# Delhi                                  64231244  254461712   364821900
# Goa                                     1244738    4114941     9080241
# Gujarat                                39761960  134749574   231865328
# Haryana                                31843908  113047107   226926755
# ...

# %%
Total_transaction_amount=pd.crosstab(index=State_txn['State'],columns=State_txn['Year'],values=State_txn['Amount (INR)'],aggfunc='sum')
Total_transaction_amount
# Out:
# Year                                          2018          2019  \
# State
# Andaman & Nicobar Islands             1.890761e+08  4.734648e+08
# Andhra Pradesh                        1.220720e+11  5.377914e+11
# Arunachal Pradesh                     1.127124e+09  3.465824e+09
# Assam                                 1.320755e+10  4.718950e+10
# Bihar                                 6.808569e+10  2.656415e+11
# Chandigarh                            4.976605e+09  1.251134e+10
# Chhattisgarh                          2.213205e+10  7.649396e+10
# Dadra & Nagar Haveli and Daman & Diu  1.584119e+09  3.855924e+09
# Delhi                                 9.575651e+10  3.723972e+11
# Goa                                   2.648633e+09  7.991018e+09
# Gujarat                               6.243806e+10  2.213301e+11
# Haryana                               5.987994e+10  1.984020e+11
# Himachal Pradesh                      6.187248e+09  2.110055e+10
# ...

# %% [markdown]
# ### 2 identify the top 5 with the highest transaction volumes and the top 5 states with the lowest transaction volumns. display the result

# %%
# adding column of total_tansaction volume to total_transaction
Total_transaction['Transaction_volume'] = Total_transaction.sum(axis=1)
Total_transaction
# Out:
# Year                                       2018       2019        2020  \
# State
# Andaman & Nicobar Islands                 58021     133104      446274
# Andhra Pradesh                         77779112  297180254   763616699
# Arunachal Pradesh                        435229    1314871     3547905
# Assam                                   8806777   22691015    47135224
# Bihar                                  44556885  131986927   266563978
# Chandigarh                              2383031    5884404     8861323
# Chhattisgarh                           13933118   45826483    98023091
# Dadra & Nagar Haveli and Daman & Diu    1044832    2559192     4807834
# Delhi                                  64231244  254461712   364821900
# Goa                                     1244738    4114941     9080241
# Gujarat                                39761960  134749574   231865328
# Haryana                                31843908  113047107   226926755
# ...

# %% [markdown]
# ### identifying the top 5 highest transaction volume

# %%
(Total_transaction.sort_values(by='Transaction_volume',ascending = False)).head(5)
# Out:
# Year                 2018       2019        2020        2021  \
# State
# Karnataka        99925678  610519200  1216153117  1054446538
# Maharashtra     116301535  526225123  1099666770  1091476726
# Telangana        67541293  439968715   931480581   908439654
# Andhra Pradesh   77779112  297180254   763616699   642515104
# Rajasthan        52782208  246343185   543585579   540207958
#
# Year            Transaction_volume
# State
# Karnataka               2981044533
# Maharashtra             2833670154
# Telangana               2347430243
# Andhra Pradesh          1781091169
# Rajasthan               1382918930

# %% [markdown]
# ### identifying the top 5 lowest transaction volume

# %%
(Total_transaction.sort_values(by='Transaction_volume',ascending = True)).head(5)
# Out:
# Year                         2018     2019     2020     2021  \
# State
# Lakshadweep                  6255    12276    32610    20469
# Andaman & Nicobar Islands   58021   133104   446274   586166
# Ladakh                      81174   292019   831785   675131
# Mizoram                    140170   369310   929381   723915
# Meghalaya                  388850  1113558  2489265  1657240
#
# Year                       Transaction_volume
# State
# Lakshadweep                             71610
# Andaman & Nicobar Islands             1223565
# Ladakh                                1880109
# Mizoram                               2162776
# Meghalaya                             5648913

# %% [markdown]
# ### 2.2 Identify the most common transaction tyeps in each state and quarter

# %% [markdown]
# ## 1 For each state and quarter, determine the most frequent transaction type. display the result in tabular fortmat

# %%
grouped_data = State_TxnSplit.groupby(['State','Quarter','Transaction Type'])['Transactions'].sum().reset_index()

# %%
grouped_data = pd.DataFrame(grouped_data)
grouped_data.head(15)
# Out:
#                         State  Quarter          Transaction Type  Transactions
# 0   Andaman & Nicobar Islands        1        Financial Services          1045
# 1   Andaman & Nicobar Islands        1         Merchant payments         59571
# 2   Andaman & Nicobar Islands        1                    Others          1956
# 3   Andaman & Nicobar Islands        1     Peer-to-peer payments        138772
# 4   Andaman & Nicobar Islands        1  Recharge & bill payments        121850
# 5   Andaman & Nicobar Islands        2        Financial Services          1318
# 6   Andaman & Nicobar Islands        2         Merchant payments         93781
# 7   Andaman & Nicobar Islands        2                    Others          2728
# 8   Andaman & Nicobar Islands        2     Peer-to-peer payments        171131
# 9   Andaman & Nicobar Islands        2  Recharge & bill payments        180447
# 10  Andaman & Nicobar Islands        3        Financial Services           664
# ...

# %%
max_info = grouped_data.groupby(['State','Quarter'])['Transactions'].max().reset_index()

# %%
merged_df = pd.merge(grouped_data, max_info, on=['State','Quarter', 'Transactions'], how='inner',)

# %%
merged_df # most frequent transaction type for each state & quarter
# Out:
#                          State  Quarter          Transaction Type  \
# 0    Andaman & Nicobar Islands        1     Peer-to-peer payments
# 1    Andaman & Nicobar Islands        2  Recharge & bill payments
# 2    Andaman & Nicobar Islands        3  Recharge & bill payments
# 3    Andaman & Nicobar Islands        4     Peer-to-peer payments
# 4               Andhra Pradesh        1     Peer-to-peer payments
# ..                         ...      ...                       ...
# 139                Uttarakhand        4     Peer-to-peer payments
# 140                West Bengal        1     Peer-to-peer payments
# 141                West Bengal        2     Peer-to-peer payments
# 142                West Bengal        3     Peer-to-peer payments
# 143                West Bengal        4     Peer-to-peer payments
#
#      Transactions
# 0          138772
# 1          180447
# 2           84165
# 3          110018
# 4       255236515
# ..            ...
# 139      11515030
# ...

# %% [markdown]
# ### 2.3 Determine the device brand with the highest number of registered used in each state

# %% [markdown]
# ### 1. Identify the device brand with the highest number of registered user in each state.Display the results in a tabular form.

# %%
State_DeviceData.head()
# Out:
#                        State  Year  Quarter    Brand  Registered Users  \
# 0  Andaman & Nicobar Islands  2018        1   Xiaomi              1665
# 1  Andaman & Nicobar Islands  2018        1  Samsung              1445
# 2  Andaman & Nicobar Islands  2018        1     Vivo               982
# 3  Andaman & Nicobar Islands  2018        1     Oppo               501
# 4  Andaman & Nicobar Islands  2018        1  OnePlus               332
#
#    Percentage
# 0    0.247033
# 1    0.214392
# 2    0.145697
# 3    0.074332
# 4    0.049258

# %%
device_data_grouped =State_DeviceData.groupby(['State','Brand'])['Registered Users'].sum().reset_index()
device_data_grouped.loc[65:88]
# Out:
#                                    State     Brand  Registered Users
# 65                            Chandigarh  Micromax              6002
# 66                            Chandigarh  Motorola             89006
# 67                            Chandigarh   OnePlus            112979
# 68                            Chandigarh      Oppo            466439
# 69                            Chandigarh    Others            323440
# 70                            Chandigarh    Realme            136203
# 71                            Chandigarh   Samsung            756667
# 72                            Chandigarh      Vivo            604600
# 73                            Chandigarh    Xiaomi            896628
# 74                          Chhattisgarh     Apple            587820
# 75                          Chhattisgarh    Huawei             69286
# 76                          Chhattisgarh    Lenovo            305245
# 77                          Chhattisgarh  Micromax           3008142
# ...

# %%
State_device_highest = device_data_grouped.groupby(['State'])['Registered Users'].max().reset_index()
State_device_highest
# Out:
#                                    State  Registered Users
# 0              Andaman & Nicobar Islands             97889
# 1                         Andhra Pradesh          40061549
# 2                      Arunachal Pradesh            437803
# 3                                  Assam           6979357
# 4                                  Bihar          33721314
# 5                             Chandigarh            896628
# 6                           Chhattisgarh           8763373
# 7   Dadra & Nagar Haveli and Daman & Diu            638834
# 8                                  Delhi          24114984
# 9                                    Goa           1208672
# 10                               Gujarat          28942157
# 11                               Haryana          21102142
# 12                      Himachal Pradesh           3978888
# 13                       Jammu & Kashmir           3471820
# 14                             Jharkhand          12824023
# ...

# %%
devicebrand_highest_regestered =pd.merge(device_data_grouped,State_device_highest,on =['State','Registered Users'],how='inner')
devicebrand_highest_regestered
# Out:
#                                    State    Brand  Registered Users
# 0              Andaman & Nicobar Islands   Xiaomi             97889
# 1                         Andhra Pradesh   Xiaomi          40061549
# 2                      Arunachal Pradesh   Xiaomi            437803
# 3                                  Assam   Xiaomi           6979357
# 4                                  Bihar   Xiaomi          33721314
# 5                             Chandigarh   Xiaomi            896628
# 6                           Chhattisgarh   Xiaomi           8763373
# 7   Dadra & Nagar Haveli and Daman & Diu   Xiaomi            638834
# 8                                  Delhi   Xiaomi          24114984
# 9                                    Goa   Xiaomi           1208672
# 10                               Gujarat   Xiaomi          28942157
# 11                               Haryana   Xiaomi          21102142
# 12                      Himachal Pradesh   Xiaomi           3978888
# ...

# %% [markdown]
# ### 2.4 Create a list of the top district per state based on population

# %% [markdown]
# ### 1 For each state identify the district with the highest population display the result in tabular format

# %%
District_Demographics.head()
# Out:
#             State       District Headquarters  Population  Area (sq km)  \
# 0  Andhra Pradesh      Anantapur    Anantapur     4083315       19130.0
# 1  Andhra Pradesh       Chittoor     Chittoor     4170468       15152.0
# 2  Andhra Pradesh  East Godavari     Kakinada     5151549       10807.0
# 3  Andhra Pradesh         Guntur       Guntur     4889230       11391.0
# 4  Andhra Pradesh            YSR       Kadapa     2884524       15359.0
#
#    Density  Code Alternate Name
# 0      213  AP01      Anantapur
# 1      275  AP02       Chittoor
# 2      477  AP03  East Godavari
# 3      429  AP04         Guntur
# 4      188  AP13            YSR

# %%
s_d_p = District_Demographics.groupby('State')['Population'].max()
s_d_p
# Out:
# State
# Andaman & Nicobar Islands                 238142
# Andhra Pradesh                           5151549
# Arunachal Pradesh                         176385
# Assam                                    2826006
# Bihar                                    5772804
# Chandigarh                               1055450
# Chhattisgarh                             2160876
# Dadra & Nagar Haveli and Daman & Diu      343709
# Delhi                                    3656539
# Goa                                       817761
# Gujarat                                  7208200
# Haryana                                  1798954
# Himachal Pradesh                         1507223
# Jammu & Kashmir                          1526406
# Jharkhand                                2912022
# Karnataka                                9588910
# Kerala                                   4110956
# Ladakh                                    143388
# Lakshadweep                                64473
# ...

# %%
highest_population_districts = pd.merge(District_Demographics,s_d_p,on =['State','Population'],how='inner')
highest_population_districts[['State','District','Population']] # adding the concated district and state column
# Out:
#                                    State                District  Population
# 0                         Andhra Pradesh           East Godavari     5151549
# 1                      Arunachal Pradesh              Papum Pare      176385
# 2                                  Assam                  Nagaon     2826006
# 3                                  Bihar                   Patna     5772804
# 4                           Chhattisgarh                  Raipur     2160876
# 5                                    Goa               North Goa      817761
# 6                                Gujarat               Ahmedabad     7208200
# 7                                Haryana               Faridabad     1798954
# 8                       Himachal Pradesh                  Kangra     1507223
# 9                              Jharkhand                  Ranchi     2912022
# 10                             Karnataka         Bangalore Urban     9588910
# ...

# %%
highest_population_districts['State_District'] = highest_population_districts['State'].str.cat(highest_population_districts['District'],sep='-')
highest_population_districts.head()
# Out:
#                State       District Headquarters  Population  Area (sq km)  \
# 0     Andhra Pradesh  East Godavari     Kakinada     5151549       10807.0
# 1  Arunachal Pradesh     Papum Pare        Yupia      176385        2875.0
# 2              Assam         Nagaon       Nagaon     2826006        3831.0
# 3              Bihar          Patna        Patna     5772804        3202.0
# 4       Chhattisgarh         Raipur       Raipur     2160876        2892.0
#
#    Density  Code Alternate Name                State_District
# 0      477  AP03  East Godavari  Andhra Pradesh-East Godavari
# 1       61  AR16     Papum Pare  Arunachal Pradesh-Papum Pare
# 2      738  AS27         Nagaon                  Assam-Nagaon
# 3     1803  BR26          Patna                   Bihar-Patna
# 4      750  CG24         Raipur           Chhattisgarh-Raipur

# %% [markdown]
# ### 2 create a column chart depicting the district with the highest population for each state

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Plotting the bar chart
plt.figure(figsize=(12, 6))
plt.bar(highest_population_districts['State_District'],highest_population_districts['Population'], color='Green')
# Customize plot
plt.title('districts with highest population', fontsize=16,fontweight='bold')
plt.xlabel('District&state', fontsize=12)
plt.ylabel('population', fontsize=12)
plt.xticks(rotation=90)

plt.grid(axis='y', linestyle='--', linewidth=0.5)

# %% [markdown]
# ### 2.5 Calculate the averge transaction value (ATV) for each state

# %% [markdown]
# ### 1 compute the average transaction value for each state. display the result in a tabular format

# %%
State_TxnSplit.head()
# Out:
#                        State  Year  Quarter          Transaction Type  \
# 0  Andaman & Nicobar Islands  2018        1  Recharge & bill payments
# 1  Andaman & Nicobar Islands  2018        1     Peer-to-peer payments
# 2  Andaman & Nicobar Islands  2018        1         Merchant payments
# 3  Andaman & Nicobar Islands  2018        1        Financial Services
# 4  Andaman & Nicobar Islands  2018        1                    Others
#
#    Transactions  Amount (INR)    ATV (INR)
# 0          4200  1.845307e+06   439.358921
# 1          1871  1.213866e+07  6487.790112
# 2           298  4.525072e+05  1518.480432
# 3            33  1.060142e+04   321.255149
# 4           256  1.846899e+05   721.444790

# %%
avgATV_state = State_TxnSplit.groupby('State')['ATV (INR)'].mean().reset_index()
avgATV_state
# Out:
#                                    State    ATV (INR)
# 0              Andaman & Nicobar Islands  2478.973133
# 1                         Andhra Pradesh  1115.127490
# 2                      Arunachal Pradesh  1973.155865
# 3                                  Assam  1332.828858
# 4                                  Bihar  1164.766705
# 5                             Chandigarh  1346.020343
# 6                           Chhattisgarh  1136.332633
# 7   Dadra & Nagar Haveli and Daman & Diu  1106.642239
# 8                                  Delhi  1122.063994
# 9                                    Goa  1383.950268
# 10                               Gujarat  1170.858499
# 11                               Haryana  1194.296428
# 12                      Himachal Pradesh  1314.173531
# 13                       Jammu & Kashmir  1440.873864
# 14                             Jharkhand  1089.161673
# 15                             Karnataka  1079.413996
# ...

# %% [markdown]
# ### 2 Identify the top 5 states with the highest ATV and the top 5 states with the lowest ATV. display the result

# %%
top_5_ATV = avgATV_state.sort_values(by='ATV (INR)',ascending=False).head(5)
top_5_ATV
# Out:
#                         State    ATV (INR)
# 0   Andaman & Nicobar Islands  2478.973133
# 17                     Ladakh  2414.441622
# 18                Lakshadweep  2103.477400
# 23                    Mizoram  1997.994730
# 2           Arunachal Pradesh  1973.155865

# %%
least_5_ATV = avgATV_state.sort_values(by='ATV (INR)',ascending=True).head(5)
least_5_ATV
# Out:
#              State    ATV (INR)
# 25          Odisha   852.615941
# 35     West Bengal   886.197622
# 19  Madhya Pradesh   994.101576
# 20     Maharashtra  1072.656215
# 33   Uttar Pradesh  1074.911380

# %% [markdown]
# ### 2.6 Analyze app usage trends

# %% [markdown]
# ### 1 calculate the total number of app open over the year and quater for each state. display the result in tabular format

# %%
State_txn.head(15)
# Out:
#                         State  Year  Quarter  Transactions  Amount (INR)  \
# 0   Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1   Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2   Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3   Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4   Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# 5   Andaman & Nicobar Islands  2019        2         33689  1.202547e+08
# 6   Andaman & Nicobar Islands  2019        3         33770  1.140718e+08
# 7   Andaman & Nicobar Islands  2019        4         35159  1.368385e+08
# 8   Andaman & Nicobar Islands  2020        1         41298  1.614763e+08
# 9   Andaman & Nicobar Islands  2020        2         62962  1.696450e+08
# 10  Andaman & Nicobar Islands  2020        3        117483  3.380194e+08
# 11  Andaman & Nicobar Islands  2020        4        224531  6.272827e+08
# ...

# %%
app_opens = State_txn.groupby(['State','Year','Quarter']) ['App Opens'].sum()
app_opens = app_opens.reset_index()
app_opens
# Out:
#                          State  Year  Quarter  App Opens
# 0    Andaman & Nicobar Islands  2018        1          0
# 1    Andaman & Nicobar Islands  2018        2          0
# 2    Andaman & Nicobar Islands  2018        3          0
# 3    Andaman & Nicobar Islands  2018        4          0
# 4    Andaman & Nicobar Islands  2019        1          0
# ..                         ...   ...      ...        ...
# 499                West Bengal  2020        2  198589332
# 500                West Bengal  2020        3  246554831
# 501                West Bengal  2020        4  291721919
# 502                West Bengal  2021        1  316832674
# 503                West Bengal  2021        2  275341466
#
# [504 rows x 4 columns]

# %% [markdown]
# ### 2 Identify trends in app usage by creating a line plot showing the number of app opens over time for a selected state

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
s = 'Gujarat' # identify trends in app usage - Gujarat State
app_open_s = app_opens[app_opens['State']== s]
app_open_s['qtr_year'] = app_opens['Year'].astype(str)+'Q'+app_opens['Quarter'].astype(str)
app_open_s
# Out:
#        State  Year  Quarter  App Opens qtr_year
# 140  Gujarat  2018        1          0   2018Q1
# 141  Gujarat  2018        2          0   2018Q2
# 142  Gujarat  2018        3          0   2018Q3
# 143  Gujarat  2018        4          0   2018Q4
# 144  Gujarat  2019        1          0   2019Q1
# 145  Gujarat  2019        2   34890301   2019Q2
# 146  Gujarat  2019        3  129441484   2019Q3
# 147  Gujarat  2019        4  147973757   2019Q4
# 148  Gujarat  2020        1  165605122   2020Q1
# 149  Gujarat  2020        2  155264359   2020Q2
# 150  Gujarat  2020        3  184402472   2020Q3
# 151  Gujarat  2020        4  230497353   2020Q4
# 152  Gujarat  2021        1  264732874   2021Q1
# 153  Gujarat  2021        2  282432543   2021Q2

# %%
plt.figure(figsize = (12,8)) # Plotting Line Chart
plt.plot(app_open_s['qtr_year'],app_open_s['App Opens'],marker = 'o')
plt.title("App usage - Gujarat")
plt.xlabel("Timeframe")
plt.ylabel("App opens")
plt.show()

# %% [markdown]
# ### insights
#
#  # 1. the is a raise in app opens in gujarat after 2019 q1

# %% [markdown]
# ### 2.7 Distribution of transaction type

# %% [markdown]
# ### 1 Create a bar chart showing the distribution of diffrent transaction type for each state for the most recent quarter in the dataset

# %%
most_recent_quater = State_TxnSplit.groupby(['Year','Quarter']).size().reset_index(name = 'counts').sort_values(by = ['Year','Quarter'],ascending = False).iloc[0]
most_recent_quater
# Out:
# Year       2021
# Quarter       2
# counts      180
# Name: 13, dtype: int64

# %%
most_recent_txn = State_TxnSplit[(State_TxnSplit['Year']==most_recent_quater['Year'])
                              &   (State_TxnSplit['Quarter']==most_recent_quater['Quarter'])]
most_recent_txn
# Out:
#                           State  Year  Quarter          Transaction Type  \
# 65    Andaman & Nicobar Islands  2021        2     Peer-to-peer payments
# 66    Andaman & Nicobar Islands  2021        2  Recharge & bill payments
# 67    Andaman & Nicobar Islands  2021        2         Merchant payments
# 68    Andaman & Nicobar Islands  2021        2        Financial Services
# 69    Andaman & Nicobar Islands  2021        2                    Others
# ...                         ...   ...      ...                       ...
# 2509                West Bengal  2021        2     Peer-to-peer payments
# 2510                West Bengal  2021        2         Merchant payments
# 2511                West Bengal  2021        2  Recharge & bill payments
# 2512                West Bengal  2021        2        Financial Services
# 2513                West Bengal  2021        2                    Others
#
#       Transactions  Amount (INR)    ATV (INR)
# ...

# %%
txn_type_dis = most_recent_txn.groupby(['Transaction Type'])['Transactions'].sum().reset_index()
txn_type_dis
# Out:
#            Transaction Type  Transactions
# 0        Financial Services       3397356
# 1         Merchant payments    1499624295
# 2                    Others       9061701
# 3     Peer-to-peer payments    1744265068
# 4  Recharge & bill payments     685022045

# %%
plt.bar(txn_type_dis['Transaction Type'],txn_type_dis['Transactions'])
plt.title('transaction distribution for most recent qtr')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ### 2.8 Find Unique mapping between district name and district code

# %% [markdown]
# ### 1 identify the unique mapping between district name and district code from the dataset

# %%
um = District_Txn_and_Users[['District','Code']].drop_duplicates()
um
# Out:
#                         District  Code
# 0                       Nicobars  AN01
# 1       North And Middle Andaman  AN02
# 2                  South Andaman  AN03
# 42                     Anantapur  AP01
# 43                      Chittoor  AP02
# ...                          ...   ...
# 9944             Purba Bardhaman  WB19
# 9945             Purba Medinipur  WB20
# 9946                     Purulia  WB21
# 9947  South Twenty Four Parganas  WB22
# 9948              Uttar Dinajpur  WB23
#
# [732 rows x 2 columns]

# %% [markdown]
# ### 2 Create a CSV file containing the unique district name and  district code mapping

# %%
um.to_csv('Unique_distict_and_code_mapping.csv',index = False) # exportcsv file

# %% [markdown]
# ### 3 export the CSv file

# %% [markdown]
# ### Task:3 Data Quality Check

# %% [markdown]
# ### 3.1 Ensure data consistency across State and district level

# %% [markdown]
# ### 1 For each state calculate the total number of Transaction,total transaction amount and total registered users by summing up the values from district level data

# %%
District_Txn_and_Users.head()
# Out:
#                        State  Year  Quarter                  District  Code  \
# 0  Andaman & Nicobar Islands  2018        1                  Nicobars  AN01
# 1  Andaman & Nicobar Islands  2018        1  North And Middle Andaman  AN02
# 2  Andaman & Nicobar Islands  2018        1             South Andaman  AN03
# 3  Andaman & Nicobar Islands  2018        2                  Nicobars  AN01
# 4  Andaman & Nicobar Islands  2018        2  North And Middle Andaman  AN02
#
#    Transactions  Amount (INR)    ATV (INR)  Registered Users  App Opens
# 0           528  1.139849e+06  2158.804548               262          0
# 1           442  9.316631e+05  2107.835016               632          0
# 2          5688  1.256025e+07  2208.201361              5846          0
# 3          1120  3.072437e+06  2743.247239               351          0
# 4           825  1.317863e+06  1597.409798               911          0

# %%
district_sums = District_Txn_and_Users.groupby('State').agg({
    'Transactions': 'sum',
    'Amount (INR)': 'sum',
    'Registered Users': 'sum'
})
district_sums
# Out:
#                                       Transactions  Amount (INR)  \
# State
# Andaman & Nicobar Islands                  1223565  3.641818e+09
# Andhra Pradesh                          1781091169  3.860292e+12
# Arunachal Pradesh                          8043799  2.225183e+10
# Assam                                    123577981  2.814087e+11
# Bihar                                    713643889  1.639579e+12
# Chandigarh                                25516542  5.371208e+10
# Chhattisgarh                             241908549  4.156353e+11
# Dadra & Nagar Haveli and Daman & Diu      12462185  1.865878e+10
# Delhi                                   1011031124  1.649942e+12
# Goa                                       24481604  4.427187e+10
# Gujarat                                  612992823  1.105329e+12
# Haryana                                  567751410  1.059832e+12
# Himachal Pradesh                          52987445  9.786546e+10
# ...

# %%
state_sums = State_txn.set_index('State')[['Transactions', 'Amount (INR)', 'Registered Users']]
state_sums
# Out:
#                            Transactions  Amount (INR)  Registered Users
# State
# Andaman & Nicobar Islands          6658  1.463176e+07              6740
# Andaman & Nicobar Islands         11340  2.833854e+07              9405
# Andaman & Nicobar Islands         16265  5.555747e+07             12149
# Andaman & Nicobar Islands         23758  9.054834e+07             15222
# Andaman & Nicobar Islands         30486  1.022997e+08             18596
# ...                                 ...           ...               ...
# West Bengal                    57676797  1.000994e+11          13222022
# West Bengal                    79954504  1.568134e+11          14448366
# West Bengal                   100340645  1.991655e+11          15662093
# West Bengal                   118254052  2.429372e+11          16808799
# West Bengal                   141897437  2.794348e+11          17979979
#
# [504 rows x 3 columns]

# %% [markdown]
# ### 2 Compare the result with the corresponding values at the state level to ensure they match

# %%
discrepancies = state_sums - district_sums
discrepancies
# Out:
#                            Transactions  Amount (INR)  Registered Users
# State
# Andaman & Nicobar Islands      -1216907 -3.627186e+09           -401656
# Andaman & Nicobar Islands      -1212225 -3.613479e+09           -398991
# Andaman & Nicobar Islands      -1207300 -3.586260e+09           -396247
# Andaman & Nicobar Islands      -1199807 -3.551270e+09           -393174
# Andaman & Nicobar Islands      -1193079 -3.539518e+09           -389800
# ...                                 ...           ...               ...
# West Bengal                  -884609244 -1.352607e+12        -131020161
# West Bengal                  -862331537 -1.295893e+12        -129793817
# West Bengal                  -841945396 -1.253541e+12        -128580090
# West Bengal                  -824031989 -1.209770e+12        -127433384
# West Bengal                  -800388604 -1.173272e+12        -126262204
#
# [504 rows x 3 columns]

# %% [markdown]
# ### 3 Display any discrepancies found between the district level and state level

# %%
print(discrepancies[discrepancies != 0].dropna())
# Out:
#                            Transactions  Amount (INR)  Registered Users
# State
# Andaman & Nicobar Islands      -1216907 -3.627186e+09           -401656
# Andaman & Nicobar Islands      -1212225 -3.613479e+09           -398991
# Andaman & Nicobar Islands      -1207300 -3.586260e+09           -396247
# Andaman & Nicobar Islands      -1199807 -3.551270e+09           -393174
# Andaman & Nicobar Islands      -1193079 -3.539518e+09           -389800
# ...                                 ...           ...               ...
# West Bengal                  -884609244 -1.352607e+12        -131020161
# West Bengal                  -862331537 -1.295893e+12        -129793817
# West Bengal                  -841945396 -1.253541e+12        -128580090
# West Bengal                  -824031989 -1.209770e+12        -127433384
# West Bengal                  -800388604 -1.173272e+12        -126262204
#
# [503 rows x 3 columns]

# %% [markdown]
# ### Task:4 Data merging and Advanced Analysis

# %% [markdown]
# ### 4.1 Ratio of users to population by state

# %% [markdown]
# ### 1 Merge the State_Txn and Users dataset with the District_Demographics dataset to calculate the ratio of registered users to population for each state display the result in tabular form

# %%
# Step 1: Aggregate population by state from the District Demographics dataset
state_population = District_Demographics .groupby('State')['Population'].sum().reset_index()
state_population
# Out:
#                                    State  Population
# 0              Andaman & Nicobar Islands      380581
# 1                         Andhra Pradesh    49378776
# 2                      Arunachal Pradesh     1606047
# 3                                  Assam    34461385
# 4                                  Bihar   103817951
# 5                             Chandigarh     1055450
# 6                           Chhattisgarh    25867958
# 7   Dadra & Nagar Haveli and Daman & Diu      586956
# 8                                  Delhi    16787941
# 9                                    Goa     1457723
# 10                               Gujarat    65930328
# 11                               Haryana    25855357
# 12                      Himachal Pradesh     6856509
# 13                       Jammu & Kashmir    12258093
# 14                             Jharkhand    32966238
# 15                             Karnataka    60965960
# 16                                Kerala    33387677
# ...

# %%
# Step 2: Merge State_Txn and Users dataset with the aggregated state population
state_users_population = pd.merge(State_txn,state_population, on='State', how='inner')
state_users_population
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens  Population
# ...

# %%
# Step 3: Calculate the ratio of registered users to population
state_users_population['Users_to_Population_Ratio'] = (
    state_users_population['Registered Users'] / state_users_population['Population']
)
state_users_population
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens  Population  \
# ...

# %%
# Step 4: Display the results in a tabular format
result_table = state_users_population[['State', 'Registered Users', 'Population', 'Users_to_Population_Ratio']]
print("Ratio of Users to Population by State:")
print(result_table)
# Out:
# Ratio of Users to Population by State:
#                          State  Registered Users  Population  \
# 0    Andaman & Nicobar Islands              6740      380581
# 1    Andaman & Nicobar Islands              9405      380581
# 2    Andaman & Nicobar Islands             12149      380581
# 3    Andaman & Nicobar Islands             15222      380581
# 4    Andaman & Nicobar Islands             18596      380581
# ..                         ...               ...         ...
# 499                West Bengal          13222022    92828987
# 500                West Bengal          14448366    92828987
# 501                West Bengal          15662093    92828987
# 502                West Bengal          16808799    92828987
# 503                West Bengal          17979979    92828987
#
#      Users_to_Population_Ratio
# 0                     0.017710
# 1                     0.024712
# 2                     0.031922
# 3                     0.039997
# 4                     0.048862
# ...

# %% [markdown]
# ### 2 create a column chart depicting the ratio of users to population by state

# %%
# Step 5: Create a column chart to visualize the ratio
plt.figure(figsize=(12, 8))
plt.bar(result_table['State'], result_table['Users_to_Population_Ratio'], color='skyblue')
plt.title('Ratio of Registered Users to Population by State', fontsize=14)
plt.xlabel('State', fontsize=12)
plt.ylabel('Users to Population Ratio', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ### 4.2 Correlate population density with transaction volumn

# %% [markdown]
# ### 1 Merge the District_Txn_and_Users dataset and with the District_Demographics dataset

# %%
district_merged = pd.merge(District_Txn_and_Users,District_Demographics,on = ['State','District','Code'])
district_merged.head()
# Out:
#                        State  Year  Quarter       District  Code  \
# 0  Andaman & Nicobar Islands  2018        1  South Andaman  AN03
# 1  Andaman & Nicobar Islands  2018        2  South Andaman  AN03
# 2  Andaman & Nicobar Islands  2018        3  South Andaman  AN03
# 3  Andaman & Nicobar Islands  2018        4  South Andaman  AN03
# 4  Andaman & Nicobar Islands  2019        1  South Andaman  AN03
#
#    Transactions  Amount (INR)    ATV (INR)  Registered Users  App Opens  \
# 0          5688  1.256025e+07  2208.201361              5846          0
# 1          9395  2.394824e+07  2549.040502              8143          0
# 2         13511  4.426811e+07  3276.449742             10474          0
# 3         20136  7.541184e+07  3745.125189             13133          0
# 4         25683  8.550197e+07  3329.127142             15961          0
#
#   Headquarters  Population  Area (sq km)  Density Alternate Name
# 0   Port Blair      238142        2672.0       89  South Andaman
# ...

# %% [markdown]
# ### 2 Calculate the correlation between population density and transaction volumn

# %%
district_merged[['Density','Transactions']].corr().iloc[0,1]
# Out:
# 0.30770410875592774

# %% [markdown]
# ### 3 create a scatter plot to visualize the correlation between population density and transaction volumn

# %%
plt.scatter(district_merged['Density'],district_merged['Transactions'])

# %% [markdown]
# ### 4.3 Average Transaction amount per user

# %% [markdown]
# ### 1 merge relavent dataset to calculate the average transaction amount per user for each dataset. display the result in tabular form

# %%
# Step 1: Merge the State_Txn and Users dataset with the District Demographics dataset
state_data_merged = pd.merge(State_txn,District_Demographics, on='State', how='inner')
state_data_merged
# Out:
#                            State  Year  Quarter  Transactions  Amount (INR)  \
# 0      Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1      Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 2      Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 3      Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 4      Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# ...                          ...   ...      ...           ...           ...
# 10383                West Bengal  2021        2     141897437  2.794348e+11
# 10384                West Bengal  2021        2     141897437  2.794348e+11
# 10385                West Bengal  2021        2     141897437  2.794348e+11
# 10386                West Bengal  2021        2     141897437  2.794348e+11
# 10387                West Bengal  2021        2     141897437  2.794348e+11
#
# ...

# %%
# Step 2: Calculate the average transaction amount per user for each state
state_data_merged['Avg_Transaction_Per_User'] = state_data_merged['Amount (INR)'] / state_data_merged['Registered Users']
state_data_merged
# Out:
#                            State  Year  Quarter  Transactions  Amount (INR)  \
# 0      Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1      Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 2      Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 3      Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 4      Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# ...                          ...   ...      ...           ...           ...
# 10383                West Bengal  2021        2     141897437  2.794348e+11
# 10384                West Bengal  2021        2     141897437  2.794348e+11
# 10385                West Bengal  2021        2     141897437  2.794348e+11
# 10386                West Bengal  2021        2     141897437  2.794348e+11
# 10387                West Bengal  2021        2     141897437  2.794348e+11
#
# ...

# %%
# Step 3: Display the results in a tabular format
avg_transaction_per_user = state_data_merged[['State', 'Avg_Transaction_Per_User']].groupby('State').agg({'Avg_Transaction_Per_User': 'mean'}).reset_index()
print(avg_transaction_per_user)
avg_transaction_per_user
# Out:
#                                    State  Avg_Transaction_Per_User
# 0              Andaman & Nicobar Islands               6846.811194
# 1                         Andhra Pradesh              17502.277427
# 2                      Arunachal Pradesh               9868.093852
# 3                                  Assam               8499.768302
# 4                                  Bihar              11287.137833
# 5                             Chandigarh              12860.471685
# 6                           Chhattisgarh               9215.205433
# 7   Dadra & Nagar Haveli and Daman & Diu               6168.978161
# 8                                  Delhi              14791.885162
# 9                                    Goa               7746.679818
# 10                               Gujarat               7370.452702
# 11                               Haryana              10362.129741
# 12                      Himachal Pradesh               6373.195303
# ...

# %% [markdown]
# ### 2 Identify the top 5 states with highest average transaction amount per user and the top 5 state with lowest average transaction amount per user display the result

# %%
# Step 4: Identify the top 5 states with the highest average transaction amount per user
top_5_states_highest = avg_transaction_per_user.nlargest(5, 'Avg_Transaction_Per_User')
print("\nTop 5 States with Highest Average Transaction Amount per User:")
print(top_5_states_highest)
# Out:
# Top 5 States with Highest Average Transaction Amount per User:
#              State  Avg_Transaction_Per_User
# 31       Telangana              23774.041127
# 1   Andhra Pradesh              17502.277427
# 15       Karnataka              17318.863969
# 8            Delhi              14791.885162
# 28       Rajasthan              13708.117474

# %%
# Step 5: Identify the top 5 states with the lowest average transaction amount per user
top_5_states_lowest = avg_transaction_per_user.nsmallest(5, 'Avg_Transaction_Per_User')
print("\nTop 5 States with Lowest Average Transaction Amount per User:")
print(top_5_states_lowest)
# Out:
# Top 5 States with Lowest Average Transaction Amount per User:
#                                    State  Avg_Transaction_Per_User
# 32                               Tripura               4956.287167
# 18                           Lakshadweep               5492.605845
# 16                                Kerala               6038.016882
# 7   Dadra & Nagar Haveli and Daman & Diu               6168.978161
# 12                      Himachal Pradesh               6373.195303

# %% [markdown]
# ### 4.4 Device brand usages ratio

# %% [markdown]
# ### 1 Merge the State_DeviceData dataset and State_Txn and Users dataset

# %%
# Merging the State_DeviceData with the State_Txn and Users dataset on 'State'
merged_data = pd.merge(State_DeviceData,State_txn[['State', 'Registered Users']], on='State', how='left')
merged_data.head()
# Out:
#                        State  Year  Quarter   Brand  Registered Users_x  \
# 0  Andaman & Nicobar Islands  2018        1  Xiaomi                1665
# 1  Andaman & Nicobar Islands  2018        1  Xiaomi                1665
# 2  Andaman & Nicobar Islands  2018        1  Xiaomi                1665
# 3  Andaman & Nicobar Islands  2018        1  Xiaomi                1665
# 4  Andaman & Nicobar Islands  2018        1  Xiaomi                1665
#
#    Percentage  Registered Users_y
# 0    0.247033                6740
# 1    0.247033                9405
# 2    0.247033               12149
# 3    0.247033               15222
# 4    0.247033               18596

# %% [markdown]
# ### 2 Calculate ratio of user using each device brand to total number of registered users in each state display the result in tabular form

# %%
merged_data['Device Brand Usage Ratio'] = merged_data['Registered Users_x'] / merged_data['Registered Users_y']
merged_data
# Out:
#                            State  Year  Quarter   Brand  Registered Users_x  \
# 0      Andaman & Nicobar Islands  2018        1  Xiaomi                1665
# 1      Andaman & Nicobar Islands  2018        1  Xiaomi                1665
# 2      Andaman & Nicobar Islands  2018        1  Xiaomi                1665
# 3      Andaman & Nicobar Islands  2018        1  Xiaomi                1665
# 4      Andaman & Nicobar Islands  2018        1  Xiaomi                1665
# ...                          ...   ...      ...     ...                 ...
# 77611                West Bengal  2021        2  Others             1928653
# 77612                West Bengal  2021        2  Others             1928653
# 77613                West Bengal  2021        2  Others             1928653
# 77614                West Bengal  2021        2  Others             1928653
# 77615                West Bengal  2021        2  Others             1928653
#
# ...

# %%
# Displaying the results
device_usage_ratio = merged_data[['State', 'Brand', 'Device Brand Usage Ratio']]
device_usage_ratio.head()
# Out:
#                        State   Brand  Device Brand Usage Ratio
# 0  Andaman & Nicobar Islands  Xiaomi                  0.247033
# 1  Andaman & Nicobar Islands  Xiaomi                  0.177033
# 2  Andaman & Nicobar Islands  Xiaomi                  0.137048
# 3  Andaman & Nicobar Islands  Xiaomi                  0.109381
# 4  Andaman & Nicobar Islands  Xiaomi                  0.089535

# %% [markdown]
# ### 3 create a bar chart depecting the device brand usage ratio for each state

# %%
import matplotlib.pyplot as plt

# %%
# Plotting the bar chart
plt.figure(figsize=(12, 6))
plt.bar(device_usage_ratio['State'], device_usage_ratio['Device Brand Usage Ratio'], color='skyblue')
plt.title('Device Brand Usage Ratio by State')
plt.xlabel('State')
plt.ylabel('Device Brand Usage Ratio')
plt.xticks(rotation=90)  # Rotate state names for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task:5 Data Visualization

# %% [markdown]
# ### 5.1 plot the total transactions and amount over time for a selected state

# %% [markdown]
# ### 1  Create a line plot showing the total number of transactions and the total transaction amount over time(year and quarter) for a selected state

# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 1: Select a state (e.g., state with maximum transactions)
state_with_max_txn =State_txn['State'].iloc[State_txn['Transactions'].idxmax()]
state_with_max_txn
# Out:
# 'Maharashtra'

# %%
# Step 2: Filter the data for the selected state
selected_state_data = State_txn[State_txn['State'] == state_with_max_txn]
selected_state_data
# Out:
#            State  Year  Quarter  Transactions  Amount (INR)    ATV (INR)  \
# 280  Maharashtra  2018        1      16387034  2.171161e+10  1324.926357
# 281  Maharashtra  2018        2      22285740  3.635706e+10  1631.404532
# 282  Maharashtra  2018        3      31538538  5.226082e+10  1657.046301
# 283  Maharashtra  2018        4      46090223  7.951894e+10  1725.288616
# 284  Maharashtra  2019        1      75079069  1.114207e+11  1484.044653
# 285  Maharashtra  2019        2     101149853  1.532945e+11  1515.518466
# 286  Maharashtra  2019        3     148735581  1.996175e+11  1342.096527
# 287  Maharashtra  2019        4     201260620  2.729944e+11  1356.422477
# 288  Maharashtra  2020        1     238944081  3.199952e+11  1339.205371
# 289  Maharashtra  2020        2     184790761  2.963595e+11  1603.757220
# 290  Maharashtra  2020        3     268310924  4.403071e+11  1641.032994
# 291  Maharashtra  2020        4     407621004  6.221555e+11  1526.308813
# ...

# %%
# Step 3: Aggregate the data by year and quarter to get total transactions and total amount
selected_state_data['Year-Quarter'] = selected_state_data['Year'].astype(str) + '-' + selected_state_data['Quarter'].astype(str)
selected_state_data
# Out:
#            State  Year  Quarter  Transactions  Amount (INR)    ATV (INR)  \
# 280  Maharashtra  2018        1      16387034  2.171161e+10  1324.926357
# 281  Maharashtra  2018        2      22285740  3.635706e+10  1631.404532
# 282  Maharashtra  2018        3      31538538  5.226082e+10  1657.046301
# 283  Maharashtra  2018        4      46090223  7.951894e+10  1725.288616
# 284  Maharashtra  2019        1      75079069  1.114207e+11  1484.044653
# 285  Maharashtra  2019        2     101149853  1.532945e+11  1515.518466
# 286  Maharashtra  2019        3     148735581  1.996175e+11  1342.096527
# 287  Maharashtra  2019        4     201260620  2.729944e+11  1356.422477
# 288  Maharashtra  2020        1     238944081  3.199952e+11  1339.205371
# 289  Maharashtra  2020        2     184790761  2.963595e+11  1603.757220
# 290  Maharashtra  2020        3     268310924  4.403071e+11  1641.032994
# 291  Maharashtra  2020        4     407621004  6.221555e+11  1526.308813
# ...

# %%
# Grouping by Year-Quarter
aggregated_data = selected_state_data.groupby('Year-Quarter').agg(
    {'Transactions': 'sum', 'Amount (INR)': 'sum'}).reset_index()
aggregated_data
# Out:
#    Year-Quarter  Transactions  Amount (INR)
# 0        2018-1      16387034  2.171161e+10
# 1        2018-2      22285740  3.635706e+10
# 2        2018-3      31538538  5.226082e+10
# 3        2018-4      46090223  7.951894e+10
# 4        2019-1      75079069  1.114207e+11
# 5        2019-2     101149853  1.532945e+11
# 6        2019-3     148735581  1.996175e+11
# 7        2019-4     201260620  2.729944e+11
# 8        2020-1     238944081  3.199952e+11
# 9        2020-2     184790761  2.963595e+11
# 10       2020-3     268310924  4.403071e+11
# 11       2020-4     407621004  6.221555e+11
# 12       2021-1     517860240  7.698874e+11
# 13       2021-2     573616486  9.151151e+11

# %%
# Step 4: Create the line plot for total transactions and total transaction amount
plt.figure(figsize=(12, 6))

# Plot total transactions
sns.lineplot(x='Year-Quarter', y='Transactions', data=aggregated_data, label='Total Transactions', marker='o', color='blue')

# Plot total transaction amount
sns.lineplot(x='Year-Quarter', y='Amount (INR)', data=aggregated_data, label='Total Transaction Amount', marker='o', color='green')

# Title and labels
plt.title(f'Total Transactions and Total Transaction Amount Over Time for {state_with_max_txn}')
plt.xlabel('Year-Quarter')
plt.ylabel('Amount/Count')
plt.xticks(rotation=45)
plt.legend(title='Metrics')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.2 Create a pie chart showing the distribution of transaction tyep for a specific quarter

# %% [markdown]
# ### 1 Create a pie chart showing the distribution of diffrent transaction tyep for a selected state and quarter

# %%
# Step 1: Select a state and quarter (for example, a specific state and a specific quarter)
selected_state = 'Karnataka'  # Replace with the desired state name
selected_quarter = 1         # Replace with the desired quarter (1 to 4)

# %%
# Step 2: Filter the data for the selected state and quarter
filtered_data = State_TxnSplit[(State_TxnSplit['State'] == selected_state) & (State_TxnSplit['Quarter'] == selected_quarter)]
filtered_data
# Out:
#           State  Year  Quarter          Transaction Type  Transactions  \
# 1050  Karnataka  2018        1  Recharge & bill payments       5785292
# 1051  Karnataka  2018        1     Peer-to-peer payments       4456528
# 1052  Karnataka  2018        1         Merchant payments       1089627
# 1053  Karnataka  2018        1        Financial Services        159848
# 1054  Karnataka  2018        1                    Others        525604
# 1070  Karnataka  2019        1     Peer-to-peer payments      44049036
# 1071  Karnataka  2019        1         Merchant payments      24491960
# 1072  Karnataka  2019        1  Recharge & bill payments      16981941
# 1073  Karnataka  2019        1        Financial Services        293728
# 1074  Karnataka  2019        1                    Others        770944
# 1090  Karnataka  2020        1         Merchant payments     132970737
# 1091  Karnataka  2020        1     Peer-to-peer payments     100868460
# ...

# %%
# Step 3: Group the data by Transaction Type and calculate the total transactions for each type
transaction_distribution = filtered_data.groupby('Transaction Type')['Transactions'].sum()
transaction_distribution
# Out:
# Transaction Type
# Financial Services             844934
# Merchant payments           438151341
# Others                        3287572
# Peer-to-peer payments       340268188
# Recharge & bill payments    110883855
# Name: Transactions, dtype: int64

# %%
# Step 4: Create the pie chart showing the distribution of transaction types
plt.figure(figsize=(8, 8))

# Pie chart - distribution of transaction types
plt.pie(transaction_distribution, labels=transaction_distribution.index, autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0'])

# Title
plt.title(f'Distribution of Transaction Types for {selected_state} in Quarter {selected_quarter}')

# Show the pie chart
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.3 Visualize the population density of district in a selected state

# %% [markdown]
# ### 1 Create a bar plot showing the population density of district in a selected state

# %%
# Step 1: Select the state for which you want to analyze the population density
selected_state = 'Karnataka'  # Replace with the desired state name

# %%
# Step 2: Filter the data to get the districts for the selected state
filtered_district_data = District_Demographics[District_Demographics['State'] == selected_state]
filtered_district_data
# Out:
#          State          District     Headquarters  Population  Area (sq km)  \
# 231  Karnataka          Bagalkot         Bagalkot     1890826        6583.0
# 232  Karnataka           Ballari          Ballari     1400970        4252.0
# 233  Karnataka           Belgaum          Belgaum     4778439       13415.0
# 234  Karnataka   Bangalore Rural        Bangalore      987257        2239.0
# 235  Karnataka   Bangalore Urban        Bangalore     9588910        2190.0
# 236  Karnataka             Bidar            Bidar     1700018        5448.0
# 237  Karnataka           Bijapur          Bijapur     2175102       10517.0
# 238  Karnataka   Chamarajanagara  Chamarajanagara     1020962        5102.0
# 239  Karnataka   Chikkaballapura  Chikkaballapura     1254377        4208.0
# 240  Karnataka       Chikmagalur      Chikmagalur     1137753        7201.0
# 241  Karnataka       Chitradurga      Chitradurga     1660378        8437.0
# ...

# %%
# Bar plot - population density by district
plt.bar(filtered_district_data['District'], filtered_district_data['Density'], color='skyblue')

# Adding labels and title
plt.xlabel('District')
plt.ylabel('Population Density (per sq km)')
plt.title(f'Population Density of Districts in {selected_state}')
plt.xticks(rotation=90)  # Rotate district names for better readability

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task:6 Insights and Conclusions

# %% [markdown]
# ### 6.1 Identify the trends or patterns in the transaction data

# %% [markdown]
# ### 1 Analyze the transaction data to identify any noticeble trends to pattern summarise your finding

# %%
# Step 1: Aggregate the data by year and quarter
State_txn['Year_Quarter'] = State_txn['Year'].astype(str) + ' Q' + State_txn['Quarter'].astype(str)
State_txn
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens Year_Quarter
# ...

# %%
# Aggregate total transactions, total amount, and average transaction value (ATV) by Year and Quarter
aggregated_data = State_txn.groupby('Year_Quarter').agg(
    total_transactions=('Transactions', 'sum'),
    total_amount=('Amount (INR)', 'sum'),
    avg_atv=('ATV (INR)', 'mean')
).reset_index()
aggregated_data
# Out:
#    Year_Quarter  total_transactions  total_amount      avg_atv
# 0       2018 Q1           134425599  1.718334e+11  1451.615091
# 1       2018 Q2           187365440  3.043742e+11  1842.088393
# 2       2018 Q3           341299764  4.751015e+11  1863.218199
# 3       2018 Q4           417111607  6.717362e+11  2044.307458
# 4       2019 Q1           708992981  9.900214e+11  1816.810151
# 5       2019 Q2           815380896  1.354214e+12  2097.949214
# 6       2019 Q3          1095009675  1.672559e+12  1980.726261
# 7       2019 Q4          1460443663  2.259894e+12  2055.205465
# 8       2020 Q1          1623038046  2.697112e+12  2067.352192
# 9       2020 Q2          1448608890  2.646145e+12  2020.310217
# 10      2020 Q3          2033051183  3.902053e+12  2198.818903
# 11      2020 Q4          2869276622  5.395851e+12  2204.966986
# 12      2021 Q1          3457585463  5.611799e+12  2159.102630
# 13      2021 Q2          3941370465  7.476466e+12  2106.130444

# %%
# Step 2: Create line graphs to visualize trends over time

plt.figure(figsize=(12, 8))

# Subplot 1: Total Transactions over time
plt.subplot(3, 1, 1)
plt.plot(aggregated_data['Year_Quarter'], aggregated_data['total_transactions'], marker='o', color='b')
plt.title('Total Transactions Over Time')
plt.xlabel('Year and Quarter')
plt.ylabel('Total Transactions')
plt.xticks(rotation=90)

# Subplot 2: Total Transaction Amount over time
plt.subplot(3, 1, 2)
plt.plot(aggregated_data['Year_Quarter'], aggregated_data['total_amount'], marker='o', color='g')
plt.title('Total Transaction Amount (INR) Over Time')
plt.xlabel('Year and Quarter')
plt.ylabel('Total Amount (INR)')
plt.xticks(rotation=90)

# Subplot 3: Average Transaction Value (ATV) over time
plt.subplot(3, 1, 3)
plt.plot(aggregated_data['Year_Quarter'], aggregated_data['avg_atv'], marker='o', color='r')
plt.title('Average Transaction Value (ATV) Over Time')
plt.xlabel('Year and Quarter')
plt.ylabel('Average Transaction Value (INR)')
plt.xticks(rotation=90)

# Layout adjustments for readability
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.2 Correlation demographic data with transaction data

# %% [markdown]
# ### 1 Find correlation between demographic data and transaction data summarise your findings

# %%
# Merge the District transaction data with the District demographics data
merged_data = pd.merge(District_Txn_and_Users,District_Demographics, on=["State", "District"], how="inner")
merged_data
# Out:
#                           State  Year  Quarter           District Code_x  \
# 0     Andaman & Nicobar Islands  2018        1      South Andaman   AN03
# 1     Andaman & Nicobar Islands  2018        2      South Andaman   AN03
# 2     Andaman & Nicobar Islands  2018        3      South Andaman   AN03
# 3     Andaman & Nicobar Islands  2018        4      South Andaman   AN03
# 4     Andaman & Nicobar Islands  2019        1      South Andaman   AN03
# ...                         ...   ...      ...                ...    ...
# 8787                West Bengal  2021        2  Paschim Medinipur   WB18
# 8788                West Bengal  2021        2    Purba Bardhaman   WB19
# 8789                West Bengal  2021        2    Purba Medinipur   WB20
# 8790                West Bengal  2021        2            Purulia   WB21
# 8791                West Bengal  2021        2     Uttar Dinajpur   WB23
#
#       Transactions  Amount (INR)    ATV (INR)  Registered Users  App Opens  \
# ...

# %%
# Select relevant columns for correlation analysis
data_for_correlation = merged_data[['Density', 'Transactions', 'Amount (INR)']]
data_for_correlation
# Out:
#       Density  Transactions  Amount (INR)
# 0          89          5688  1.256025e+07
# 1          89          9395  2.394824e+07
# 2          89         13511  4.426811e+07
# 3          89         20136  7.541184e+07
# 4          89         25683  8.550197e+07
# ...       ...           ...           ...
# 8787      757       5051834  1.030351e+10
# 8788      890       3920729  7.572502e+09
# 8789     1076       6418522  1.515507e+10
# 8790      468       1895981  2.790996e+09
# 8791      956       2253385  5.564221e+09
#
# [8792 rows x 3 columns]

# %%
# Calculate correlations between Population Density and Transaction Volume (Transactions) and Total Transaction Amount
correlation_density_transactions = data_for_correlation['Density'].corr(data_for_correlation['Transactions'])
correlation_density_amount = data_for_correlation['Density'].corr(data_for_correlation['Amount (INR)'])

# %%
# Display correlation results
print(f"Correlation between Population Density and Transaction Volume: {correlation_density_transactions}")
print(f"Correlation between Population Density and Total Transaction Amount: {correlation_density_amount}")
# Out:
# Correlation between Population Density and Transaction Volume: 0.3077041087559284
# Correlation between Population Density and Total Transaction Amount: 0.3367945166368611

# %%
# Visualize the correlation using a scatter plot
plt.figure(figsize=(10, 5))

# Scatter plot for Population Density vs Transaction Volume
plt.subplot(1, 2, 1)
plt.scatter(merged_data['Density'], merged_data['Transactions'], color='b', alpha=0.5)
plt.title('Population Density vs Transaction Volume')
plt.xlabel('Population Density')
plt.ylabel('Transaction Volume')

# Scatter plot for Population Density vs Total Transaction Amount
plt.subplot(1, 2, 2)
plt.scatter(merged_data['Density'], merged_data['Amount (INR)'], color='g', alpha=0.5)
plt.title('Population Density vs Total Transaction Amount')
plt.xlabel('Population Density')
plt.ylabel('Total Transaction Amount (INR)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.3 Summarise findings and insights

# %% [markdown]
# ### 1 Summarise the key findings and insights from your analysis provide actionable recommendation based on the data

# %% [markdown]
# ### 1. Transaction Trends Over Time:
#
# The transaction data reveals seasonal trends with peaks in certain quarters, which could be tied to festivals, holidays, or special promotional periods.
# A steady increase in transaction volume and amounts over the years is observed, likely driven by growing digital adoption and increased usage of mobile payment platforms like PhonePe.
#
# ### 2. Device Brand Usage:
#
# The data shows that certain device brands dominate in terms of registered users, with a significant share of users preferring popular brands such as Samsung and Xiaomi. This suggests that PhonePe's user base is heavily skewed towards Android devices.
# Given this, optimizing the PhonePe app for specific brands or operating systems could further improve user experience and app performance.
#
# ### 3. Demographic Insights:
#
# Population Density vs. Transaction Volume: In densely populated districts, we observed a moderate positive correlation with transaction volume. Higher population density likely translates to a higher number of users and, consequently, a higher volume of transactions. However, it’s important to note that the correlation between population density and the total transaction amount is weaker, suggesting that transaction amounts may not necessarily increase in more populated areas.
#
# ### 4. Population Density vs. Transaction Amount:
#
# Interestingly, areas with higher population density showed varying transaction amounts, which may suggest that factors like income levels, access to digital infrastructure, or the types of transactions (e.g., bill payments vs. large transfers) influence the overall transaction value more than population density alone.
#
# ### 5. Transaction Type Distribution:
#
# The most frequent transaction types are likely to be Recharge & Bill Payments and Peer-to-Peer Payments, especially in the quarters where the transaction volume was the highest. This suggests that PhonePe is mainly used for day-to-day payments and financial transfers, making it an essential tool for basic financial activities.
#
# ### 6. State-Level Insights:
#
# States with larger populations, such as Uttar Pradesh, Maharashtra, and Tamil Nadu, show high transaction volumes, but the average transaction value (ATV) varies greatly by state. This highlights the need for state-specific marketing campaigns or offers that cater to the unique financial behaviors in these regions.
#
# ### 7. App Usage Trends:
# App opens and user engagement also show seasonal variations, with app usage peaking during specific months or events. This data can be leveraged for targeted advertising and in-app promotions.
